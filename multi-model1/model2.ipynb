# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as ex

# %%
df=pd.read_csv("cleaned_data.csv")
df
# Out:
#       StudyHours  PapersPracticed  PreviousMarks  SleepingHours  \
# 0            5.0              2.0           69.0              8
# 1            2.0              8.0           46.0              4
# 2            7.0              5.0           56.0              7
# 3            6.0              5.0           42.0              8
# 4            7.0              6.0           53.0              4
# ...          ...              ...            ...            ...
# 7740         5.0              3.0           90.0              8
# 7741         3.0              4.0            5.0              4
# 7742         4.0              3.0           68.0              9
# 7743         9.0              6.0           48.0              7
# 7744         2.0              6.0           46.0              6
#
#       PerformanceIndex
# 0                  5.0
# 1                 20.0
# 2                 46.0
# 3                 28.0
# 4                  4.0
# ...                ...
# 7740              78.0
# 7741              29.0
# 7742               5.0
# 7743              44.0
# 7744              24.0
#
# [7745 rows x 5 columns]

# %%
ex.scatter_3d(df,x="StudyHours",y="PapersPracticed",z="PerformanceIndex")

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=4200)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6196 entries, 6492 to 7331
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   StudyHours       6196 non-null   float64
#  1   PapersPracticed  6196 non-null   float64
# dtypes: float64(2)
# memory usage: 145.2 KB

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#y=b1x1 + b2x2 + b3x3 + b0
b0=lr.intercept_
b=lr.coef_
y=b[0]*3 + b[1]*2  + b0
y
# Out:
# np.float64(44.93553435283388)

# %%
import joblib

# %%
joblib.dump(lr,"model2.joblib")
# Out:
# ['model2.joblib']
