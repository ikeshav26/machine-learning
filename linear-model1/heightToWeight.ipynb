# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("data.csv")
df
# Out:
#     Height  Weight
# 0     1.47   52.21
# 1     1.50   53.12
# 2     1.52   54.48
# 3     1.55   55.84
# 4     1.57   57.20
# 5     1.60   58.57
# 6     1.63   59.93
# 7     1.65   61.29
# 8     1.68   63.11
# 9     1.70   64.47
# 10    1.73   66.28
# 11    1.75   68.10
# 12    1.78   69.92
# 13    1.80   72.19
# 14    1.83   74.46

# %%
plt.scatter(df['Height'],df['Weight'],color="black")

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,1:2]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
m=lr.coef_
b=lr.intercept_

# %%
y=m*1.47+b
y
# Out:
# array([[50.8066967]])

# %%
import joblib

# %%
joblib.dump(lr,"HeightToWeight.joblib")
# Out:
# ['HeightToWeight.joblib']
