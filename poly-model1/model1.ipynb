# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Synthetic_Dataset.csv")
df
# Out:
#      Temperature_Deviation  Machine_Efficiency
# 0                  -20.000              -29.25
# 1                  -19.866              -28.61
# 2                  -19.732              -25.84
# 3                  -19.599              -22.95
# 4                  -19.465              -24.02
# ..                     ...                 ...
# 295                 19.465              -24.70
# 296                 19.599              -23.88
# 297                 19.732              -26.35
# 298                 19.866              -27.18
# 299                 20.000              -29.06
#
# [300 rows x 2 columns]

# %%
plt.scatter(df['Temperature_Deviation'],df['Machine_Efficiency'])

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]

# %%
from sklearn.preprocessing import  PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=3)

# %%
x_poly=poly.fit_transform(x)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_poly,y)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_poly)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y,y_pred)
# Out:
# 0.9983459875926219

# %%
plt.scatter(x,y)
plt.plot(x,y_pred)

# %%
import joblib
joblib.dump(lr,"machine.joblib")
# Out:
# ['machine.joblib']
