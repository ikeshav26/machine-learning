# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\keshav\appdata\local\programs\python\python312\lib\site-packages (1.7.0)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\keshav\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (2.3.0)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\keshav\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\keshav\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\keshav\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv("placements_new.csv")
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.describe()
# Out:
#              cgpa     package
# count  200.000000  200.000000
# mean     6.990500    2.996050
# std      1.069409    0.691644
# min      4.260000    1.370000
# 25%      6.190000    2.487500
# 50%      6.965000    2.995000
# 75%      7.737500    3.492500
# max      9.580000    4.620000

# %%
plt.scatter(df["cgpa"],df["package"],color="black")

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]
x
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 160 entries, 79 to 102
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cgpa    160 non-null    float64
# dtypes: float64(1)
# memory usage: 2.5 KB

# %%
y_train.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 160 entries, 79 to 102
# Series name: package
# Non-Null Count  Dtype
# --------------  -----
# 160 non-null    float64
# dtypes: float64(1)
# memory usage: 2.5 KB

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
#y=mx+b

# %%
m=lr.coef_
b=lr.intercept_

# %%
y=m*8.13+b
y
# Out:
# array([3.64169819])

# %%
plt.scatter(x_train,y_train)
plt.scatter(x_test,y_test,color="black")
plt.plot(x_test,y_pred)

# %%
pip install joblib
# Out:
# Requirement already satisfied: joblib in c:\users\keshav\appdata\local\programs\python\python312\lib\site-packages (1.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import joblib

# %%
joblib.dump(lr,'cgpacal.joblib')
# Out:
# ['cgpacal.joblib']
